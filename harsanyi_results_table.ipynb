# %%
import numpy as np
import pandas as pd
import os

base_path = 'results/20250625_harsanyi_optimization_0.025/result/dataset=custom-imdb-for-bertweet-nips2024-ucb-test_model=BERTweet#pretrain_seed=0/players=players-manual_lbl=correct_baseline=unk_bg=ori#/data'

# 初始化结果列表
results = []

# 处理每个sample
for i in range(11):
    sample_path = os.path.join(base_path, f'sample{i}')
    
    # 计算I_and.npy元素和
    i_and = np.load(os.path.join(sample_path, 'I_and.npy'))
    interaction_sum = np.sum(i_and)
    
    # 获取rewards_minus_v0.npy最后一个元素
    rewards = np.load(os.path.join(sample_path, 'rewards_minus_v0.npy'))
    last_reward = rewards[-1]
    
    results.append({
        '交互和': interaction_sum,
        '输出': last_reward
    })

# 创建DataFrame
df = pd.DataFrame(results)
df.to_csv('harsanyi_12_results.csv', index=False)
df
# Out:
#          交互和        输出
# 0   8.579201  8.579202
# 1   7.351917  7.351918
# 2   7.028538  7.028529
# 3   9.037521  9.038040
# 4   7.806697  7.806718
# 5   9.012665  9.012815
# 6   6.681166  6.680867
# 7   7.919733  7.919706
# 8   9.522034  9.519035
# 9   9.204361  9.203996
# 10  3.124043  3.124143
